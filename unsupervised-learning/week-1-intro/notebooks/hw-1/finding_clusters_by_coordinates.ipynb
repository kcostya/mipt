# %%
import numpy as np
import pandas as pd
from sklearn.cluster import MeanShift
from sklearn.model_selection import train_test_split

# %%
with open('checkins.dat') as input_file:        
    newLines = []
    for line in input_file:
        newLine = [x.strip() for x in line.split('|')]
        if len(newLine) == 6 and newLine[3] and newLine[4]:
            newLines.append(newLine)

# %%
labels = newLines[0]

# %%
df = pd.DataFrame(newLines[1:], columns=newLines[0])

# %%
df.shape
# Out:
# (396634, 6)

# %%
df.head()
# Out:
#        id  user_id venue_id    latitude     longitude           created_at
# 0  984222    15824     5222  38.8951118   -77.0363658  2012-04-21 17:43:47
# 1  984234    44652     5222   33.800745     -84.41052  2012-04-21 17:43:43
# 2  984291   105054     5222  45.5234515  -122.6762071  2012-04-21 17:39:22
# 3  984318  2146539     5222   40.764462   -111.904565  2012-04-21 17:35:46
# 4  984232    93870   380645  33.4483771  -112.0740373  2012-04-21 17:38:18

# %%
df100 = df[['latitude', 'longitude']].iloc[:100000, :]

# %%
ms = MeanShift(bandwidth=0.1, min_bin_freq=15, n_jobs=-1)

# %%
# %%time
ms.fit(df100)
# Out:
# CPU times: user 12.1 s, sys: 381 ms, total: 12.5 s
# Wall time: 49.4 s
# MeanShift(bandwidth=0.1, bin_seeding=False, cluster_all=True, min_bin_freq=15,
#      n_jobs=-1, seeds=None)

# %%
ms.cluster_centers_.shape
# Out:
# (3230, 2)

# %%
offices = np.array(([33.751277, -118.188740],
                    [25.867736, -80.324116],
                    [51.503016, -0.075479],
                    [52.378894, 4.885084],
                    [39.366487, 117.036146],
                    [-33.868457, 151.205134]
                   ))

# %%
cities = ['Los Angeles', 'Miami', 'London', 'Amsterdam', 'Beijing', 'Sydney']

# %%
offices = pd.DataFrame(offices, columns = ['latitude', 'longitude'])

# %%
offices['city'] = cities

# %%
offices
# Out:
#     latitude   longitude         city
# 0  33.751277 -118.188740  Los Angeles
# 1  25.867736  -80.324116        Miami
# 2  51.503016   -0.075479       London
# 3  52.378894    4.885084    Amsterdam
# 4  39.366487  117.036146      Beijing
# 5 -33.868457  151.205134       Sydney

# %%
clusters = ms.cluster_centers_

# %%
dist_to_office = np.sum((clusters - offices[offices.city == 'London'][['latitude', 'longitude']].values)**2, axis=1)
dist_to_office = np.sqrt(dist_to_office)
idx = dist_to_office.argsort()[:20]
list(zip(clusters[idx]))
# Out:
# [(array([ 51.50299126,  -0.12553729]),),
#  (array([ 51.42676329,  -0.30373207]),),
#  (array([ 51.5741517,   0.1838708]),),
#  (array([ 51.50647877,  -0.36517727]),),
#  (array([ 51.75153 ,  -0.333892]),),
#  (array([ 51.2329101,  -0.3297445]),),
#  (array([ 51.1133388,  -0.1829137]),),
#  (array([ 51.4934557,   0.3529197]),),
#  (array([ 51.4307509,  -0.5481532]),),
#  (array([ 51.386522 ,   0.5443375]),),
#  (array([ 51.522751,  -0.720209]),),
#  (array([ 51.6664235,  -0.7286419]),),
#  (array([ 50.819522,  -0.13642 ]),),
#  (array([ 51.2940006,  -0.754624 ]),),
#  (array([ 52.2025441,   0.1312368]),),
#  (array([ 51.8157917,  -0.8166621]),),
#  (array([ 52.038601,  -0.757072]),),
#  (array([ 51.455041 ,  -0.9690884]),),
#  (array([ 50.785996,  -0.675879]),),
#  (array([ 51.7522792,  -1.2558838]),)]

# %%
dist_to_office = np.zeros(clusters.shape)
distances = pd.DataFrame(columns = cities)
locations = pd.DataFrame(columns = cities)

for city in cities:
    dist_to_office = np.sum((clusters - offices[offices.city == city][['latitude', 'longitude']].values)**2, axis=1)
    dist_to_office = np.sqrt(dist_to_office)
    distances[city] = np.sort(dist_to_office)[:20]
    idx = dist_to_office.argsort()[:20]
    locations[city] = list(zip(clusters[idx]))

# %%
distances
# Out:
#     Los Angeles     Miami    London  Amsterdam    Beijing     Sydney
# 0      0.070848  0.022674  0.050058   0.009353   0.303308   0.007835
# 1      0.195779  0.134109  0.240653   0.251502   0.827318   0.154103
# 2      0.211811  0.167406  0.268929   0.275320   1.028142   0.192227
# 3      0.222233  0.188876  0.289719   0.298373   9.188567   0.906813
# 4      0.294979  0.271301  0.358520   0.371112   9.267575   1.090489
# 5      0.304731  0.302270  0.370956   0.413724   9.327714   2.530161
# 6      0.314884  0.340846  0.404216   0.418038   9.855948   3.923192
# 7      0.338810  0.427500  0.428505   0.475003   9.932652   5.019206
# 8      0.378688  0.540471  0.478166   0.550234  10.103449   6.182523
# 9      0.386706  0.671049  0.630669   0.607774  10.211337   6.417077
# 10     0.398778  0.791199  0.645032   0.618580  10.283843   6.652980
# 11     0.409983  0.800398  0.673293   0.656872  10.618319   7.173645
# 12     0.410418  0.883592  0.686205   0.778300  10.778967   7.205982
# 13     0.433354  0.968825  0.710581   0.842025  11.274412   7.378794
# 14     0.448055  0.991121  0.729432   1.177457  11.765354   7.401202
# 15     0.463598  1.090988  0.804476   1.254316  12.746759   7.722429
# 16     0.493387  1.224173  0.866845   1.379866  13.310471   9.824364
# 17     0.574205  1.343347  0.894896   1.393220  14.107792  12.645502
# 18     0.603093  1.392512  0.935199   1.462707  14.975017  20.721260
# 19     0.619070  1.408436  1.206436   1.574691  15.623112  23.509079

# %%
locations
# Out:
#                            Los Angeles                               Miami  \
# 0   ([33.8098779553, -118.148923807],)  ([25.8456722643, -80.3188905964],)
# 1   ([33.8883253428, -118.048928172],)    ([25.78581242, -80.2179380368],)
# 2   ([33.8729860116, -118.362091147],)  ([25.7053497211, -80.2834287382],)
# 3   ([33.9725748214, -118.168370667],)  ([26.0100982493, -80.1999905857],)
# 4    ([33.983935874, -118.007404973],)  ([26.1388437868, -80.3343468368],)
# 5   ([33.8173064339, -117.891249171],)  ([26.1208626586, -80.1589066802],)
# 6   ([34.0603975546, -118.248709027],)   ([26.200584641, -80.2507161256],)
# 7   ([33.6743026598, -117.858789268],)        ([25.4687224, -80.4775569],)
# 8   ([34.0354869531, -118.438997719],)  ([26.3525711663, -80.0852787174],)
# 9   ([34.1314601492, -118.118011806],)  ([26.4888424714, -80.0700818714],)
# 10  ([34.0912975346, -117.980389453],)       ([26.649797, -80.204217325],)
# 11  ([34.1274022191, -118.351883725],)      ([25.0763098, -80.443623175],)
# 12   ([34.160210385, -118.223616573],)  ([26.7083577292, -80.0519220333],)
# 13       ([33.3408333, -118.3277778],)      ([26.81397823, -80.11615408],)
# 14  ([33.6508959929, -117.752073973],)        ([24.9242995, -80.6278404],)
# 15       ([33.3614631, -118.4396756],)        ([26.9342246, -80.0942087],)
# 16  ([34.0750788256, -117.816471886],)        ([26.4186898, -81.4172993],)
# 17  ([34.1981820709, -118.549276808],)       ([27.20893652, -80.2482145],)
# 18  ([34.0618855737, -117.671784578],)        ([25.9405556, -81.7147222],)
# 19  ([33.4516237945, -117.647024453],)            ([27.2758333, -80.355],)
#
#                                  London                          Amsterdam  \
# 0    ([51.5029912609, -0.12553728871],)  ([52.3729639903, 4.89231722258],)
# 1   ([51.4267632889, -0.303732066667],)      ([52.388501, 4.63376546667],)
# 2            ([51.5741517, 0.1838708],)               ([52.2644, 4.6347],)
# 3   ([51.5064787667, -0.365177266667],)         ([52.2738177, 5.1643425],)
# 4              ([51.75153, -0.333892],)         ([52.080058, 5.10513275],)
# 5           ([51.2329101, -0.3297445],)          ([51.974932, 4.9744262],)
# 6           ([51.1133388, -0.1829137],)           ([52.787747, 4.797934],)
# 7            ([51.4934557, 0.3529197],)           ([52.132633, 5.291266],)
# 8           ([51.4307509, -0.5481532],)           ([52.156651, 5.388438],)
# 9             ([51.386522, 0.5443375],)           ([51.924216, 4.481776],)
# 10            ([51.522751, -0.720209],)         ([52.2224835, 5.4835625],)
# 11          ([51.6664235, -0.7286419],)  ([52.0435286167, 4.32027353333],)
# 12             ([50.819522, -0.13642],)         ([51.9226067, 4.2545656],)
# 13           ([51.2940006, -0.754624],)         ([51.5601908, 5.0818877],)
# 14           ([52.2025441, 0.1312368],)         ([51.2407352, 4.5834231],)
# 15          ([51.8157917, -0.8166621],)           ([51.890125, 6.040252],)
# 16            ([52.038601, -0.757072],)           ([51.077944, 4.425129],)
# 17           ([51.455041, -0.9690884],)            ([51.252171, 5.70457],)
# 18            ([50.785996, -0.675879],)         ([53.3255453, 6.0001461],)
# 19          ([51.7522792, -1.2558838],)          ([50.8529185, 4.496433],)
#
#                          Beijing                              Sydney
# 0     ([39.121079, 117.214389],)  ([-33.8606304286, 151.204775929],)
# 1     ([39.904214, 116.407413],)     ([-34.00190615, 151.12806905],)
# 2     ([40.376322, 116.842992],)       ([-33.9522629, 151.0321372],)
# 3     ([30.593087, 114.305357],)       ([-33.7149546, 150.3114074],)
# 4     ([31.230393, 121.473704],)       ([-32.8970039, 151.7005582],)
# 5     ([31.112842, 121.381672],)       ([-35.3080556, 149.1244444],)
# 6   ([37.4562557, 126.7052062],)         ([-36.506376, 148.301203],)
# 7   ([37.5588652, 126.8029305],)        ([-31.2532183, 146.921099],)
# 8    ([37.566535, 126.9779692],)     ([-28.0673655, 153.343106667],)
# 9   ([37.2635727, 127.0286009],)        ([-27.7866521, 153.252212],)
# 10  ([37.4449168, 127.1388684],)       ([-27.4663292, 153.0148015],)
# 11  ([37.4912195, 127.4875607],)       ([-37.7133771, 145.1489162],)
# 12  ([36.3504119, 127.3845475],)       ([-37.8229826, 145.1811902],)
# 13    ([35.907757, 127.766922],)  ([-37.8090540565, 144.966681387],)
# 14   ([36.119485, 128.3445734],)        ([-37.701486, 144.8738088],)
# 15  ([35.1795543, 129.0756416],)       ([-26.3817003, 153.0983793],)
# 16     ([35.86166, 104.195397],)       ([-42.8946543, 147.3262306],)
# 17  ([33.1799153, 129.7151101],)    ([-34.9143691333, 138.6029596],)
# 18   ([25.091075, 121.5598345],)       ([-45.0311622, 168.6626435],)
# 19    ([30.658601, 104.064856],)       ([-43.5320544, 172.6362254],)

# %%
ans = str(locations.loc[0, 'Sydney'][0][0])+" "+str(locations.loc[0, 'Sydney'][0][1])
print(ans)
# Out:
# -33.8606304286 151.204775929

# %%
with open('ans.txt', 'w') as file:
    file.write(ans)
